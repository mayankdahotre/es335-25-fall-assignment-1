# %%
# !python metrics.py

# %%
# !python usage.py
# Out:
# ?0 <= 0.11092258970986608
#   Y: ?0 <= -0.6017066122293969
#       Y: ?0 <= -1.4635149481321186
#           Y: ?0 <= -1.9187712152990415
#               Y: Value -0.0771017094141042, [-0.07710171]
#               N: ?0 <= -1.5506634310661327
#                   Y: Value 0.01300189187790702, [0.01300189]
#                   N: Value -0.7537361643574896, [-0.75373616]
#           N: ?0 <= -1.2208436499710222
#               Y: ?0 <= -1.4153707420504142
#                   Y: Value -0.8895144296255233, [-0.88951443]
#                   N: Value 0.4738329209117875, [0.47383292]
#               N: ?0 <= -0.7198442083947086
#                   Y: Value 0.6565536086338297, [0.65655361]
#                   N: Value 1.8657745111447566, [1.86577451]
#       N: ?0 <= -0.46341769281246226
#           Y: ?0 <= -0.5017570435845365
#               Y: ?0 <= -0.5622875292409727
#                   Y: Value 0.23225369716100355, [0.2322537]
#                   N: Value 1.8967929826539474, [1.89679298]
# ...

# %%
# !python classification-exp.py
# Out:
# Dataset size: 100 samples with 2 features
#
#  Testing with INFORMATION_GAIN criterion:
# ...
# CLASSIFICATION PERFORMANCE REPORT
# ...
# Overall Accuracy: 0.9667 (96.67%)
# -----------------------------------------------------------------
# Class     Precision   Recall      F1-Score
# -----------------------------------------------------------------
# 0         1.0000      0.9167      0.9565
# 1         0.9474      1.0000      0.9730
# -----------------------------------------------------------------
# Macro Avg 0.9737      0.9583      0.9647
# ...
# Tree depth: 5
# Number of leaf nodes: 10
#
#  Testing with GINI_INDEX criterion:
# ...
# CLASSIFICATION PERFORMANCE REPORT
# ...
# Overall Accuracy: 0.9333 (93.33%)
# -----------------------------------------------------------------
# Class     Precision   Recall      F1-Score
# -----------------------------------------------------------------
# 0         0.9167      0.9167      0.9167
# 1         0.9444      0.9444      0.9444
# ...

# %%
# !python auto-efficiency.py

# %%
# !python experiments.py
